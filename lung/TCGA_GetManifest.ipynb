# %%
import requests
import json
import pandas as pd

# %%
files_endpt = "https://api.gdc.cancer.gov/files"

# The 'fields' parameter is passed as a comma-separated string of single names.
fields = [
    "file_name",
    #"analysis.workflow_type",
    #"experimental_strategy",
    "cases.project.primary_site",
    "cases.project.disease_type",
    "cases.diagnoses.primary_diagnosis",
    "cases.submitter_id",
    "cases.samples.portions.analytes.aliquots.submitter_id",
    "cases.diagnoses.tumor_stage",
    "cases.diagnoses.tumor_grade",
    "cases.diagnoses.progression_or_recurrence"
    "cases.diagnoses.vital_status",
    "cases.diagnoses.days_to_birth",
    "cases.diagnoses.days_to_death",
    "cases.diagnoses.morphology",
    "cases.diagnoses.tissue_or_organ_of_origin",
    "cases.samples.longest_dimension",
    "cases.samples.shortest_dimension",
    "cases.samples.pathology_report_uuid"
    #"cases.project.project_id"
]

fields = ','.join(fields)

# %% [markdown]
# ## miRNA

# %%
#miRNA filters
filters = {
    "op": "and",
    "content":[
        {
        "op": "in",
        "content":{
            "field": "files.data_type",
            "value": ["miRNA Expression Quantification"]
            }
        },
          {
        "op": "in",
        "content":{
               "field": "files.experimental_strategy",
                "value": ["miRNA-Seq"]
                }
        },
        {
        "op": "in",
        "content":{
            "field": "files.data_format",
            "value": ["TXT"]
            }
        },
        {
        "op": "in",
        "content":{
            "field": "cases.project.project_id",
            "value": ['TCGA-LUAD', 'TCGA-LUSC']
            }
        },
        {
        "op": "in",
        "content":{
            "field": "cases.project.program.name",
            "value": ["TCGA"]
            }
        }
        
    ]
}

# %%
# A POST is used, so the filter parameters can be passed directly as a Dict object.
##remove manifest to have file fields
params = {
   "return_type": "manifest",
    "filters": filters,
    "fields": fields,
    "format": "TSV",
    "size": "15000"
    }

# %%
# The parameters are passed to 'json' rather than 'params' in this case
response = requests.post(files_endpt, headers = {"Content-Type": "application/json"}, json = params)

#print(response.content.decode("utf-8"))

# %%
len(response.content.decode("utf-8"))
# Out:
# 172247

# %%
with open("manifest.txt","w") as manifest:
    manifest.write(response.content.decode("utf-8"))

# %%
params = {
    "filters": json.dumps(filters),
    "fields": "primary_site,cases.project.project_id,file_name,cases.demographic.vital_status,cases.demographic.gender,cases.diagnoses.age_at_diagnosis,cases.diagnoses.days_to_last_follow_up,cases.demographic.days_to_death,cases.demographic.days_to_birth,cases.submitter_id,samples.portions.analytes.aliquots.submitter_id,cases.diagnoses.last_known_disease_status,cases.diagnoses.tumor_stage,cases.exposures.years_smoked,cases.exposures.cigarettes_per_day,cases.samples.portions.analytes.aliquots.submitter_id,cases.samples.longest_dimension,cases.samples.shortest_dimension,cases.samples.tumor_descriptor",
    "format": "TSV",
    "size": "50000"
    }
response = requests.get("https://api.gdc.cancer.gov/files", headers = {"Content-Type": "application/json"}, params = params)
#print(response.content.decode("UTF-8"))
with open("files.txt","w") as files:
    files.write(response.content.decode("utf-8"))

# %%
df_files = pd.read_csv("files.txt", sep='\t')
df_files.drop("id", axis=1, inplace=True)
df_files.set_index("file_name", inplace=True)
df_files.rename(columns={"cases.0.samples.0.portions.0.analytes.0.aliquots.0.submitter_id":"sample_submitter_id_mirna"}, inplace=True)
df_files.head(2)
# Out:
#                                                     cases.0.demographic.days_to_birth  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                           -26451.0
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                           -19200.0
#
#                                                     cases.0.demographic.days_to_death  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                                NaN
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                                NaN
#
#                                                    cases.0.demographic.gender  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                     female
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                     female
#
#                                                    cases.0.demographic.vital_status  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                            Alive
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                            Alive
#
#                                                     cases.0.diagnoses.0.age_at_diagnosis  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                               26451.0
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                               19200.0
#
#                                                     cases.0.diagnoses.0.days_to_last_follow_up  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                                       652.0
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                                       719.0
#
#                                                    cases.0.diagnoses.0.last_known_disease_status  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                                  not reported
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                                  not reported
#
#                                                     cases.0.exposures.0.cigarettes_per_day  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                                1.643836
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                                1.095890
#
#                                                     cases.0.exposures.0.years_smoked  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                              24.0
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                               NaN
#
#                                                    cases.0.project.project_id  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                  TCGA-LUAD
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                  TCGA-LUAD
#
#                                                     cases.0.samples.0.longest_dimension  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                                  0.8
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                                  1.5
#
#                                                        sample_submitter_id_mirna  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....  TCGA-55-7726-11A-01H-2169-13
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....  TCGA-44-7672-01A-11H-2065-13
#
#                                                     cases.0.samples.0.shortest_dimension  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                                   0.4
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                                   0.8
#
#                                                     cases.0.samples.0.tumor_descriptor  \
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....                                 NaN
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....                                 NaN
#
#                                                    cases.0.submitter_id
# file_name
# 03f54564-65bb-4561-ad33-ec78b883c217.mirbase21....         TCGA-55-7726
# 28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21....         TCGA-44-7672

# %%
df_files["cases.0.samples.0.tumor_descriptor"].dropna().unique()
# Out:
# array([], dtype=float64)

# %%
df_files.to_csv("files_miRNA.dat", header=True)

# %% [markdown]
# ## FPKM

# %%
# Tissue project filters
filters = {
    "op": "and",
    "content":[
        {
        "op": "in",
        "content":{
            "field": "files.data_type",
            "value": ["Gene Expression Quantification"]
            }
        },
        {
        "op": "in",
        "content":{
               "field": "files.analysis.workflow_type",
                "value": ["HTSeq - FPKM"]
                }
        },
        {
        "op": "in",
        "content":{
            "field": "files.data_format",
            "value": ["TXT"]
            }
        },
        {
        "op": "in",
        "content":{
            "field": "cases.project.project_id",
            "value": ["TCGA-LUAD", "TCGA-LUSC"]
            }
        }
        
    ]
}

# %%
# A POST is used, so the filter parameters can be passed directly as a Dict object.
##remove manifest to have file fields
params = {
   "return_type": "manifest",
    "filters": filters,
    "fields": fields,
    "format": "TSV",
    "size": "15000"
    }

# %%
# The parameters are passed to 'json' rather than 'params' in this case
response = requests.post(files_endpt, headers = {"Content-Type": "application/json"}, json = params)

#print(response.content.decode("utf-8"))

# %%
len(response.content.decode("utf-8"))
# Out:
# 154602

# %%
with open("manifest.txt","w") as manifest:
    manifest.write(response.content.decode("utf-8"))

# %%
params = {
    "filters": json.dumps(filters),
    "fields": "primary_site,cases.project.project_id,file_name,cases.demographic.vital_status,cases.demographic.gender,cases.diagnoses.age_at_diagnosis,cases.diagnoses.days_to_last_follow_up,cases.demographic.days_to_death,cases.demographic.days_to_birth,cases.submitter_id,samples.portions.analytes.aliquots.submitter_id,cases.diagnoses.last_known_disease_status,cases.diagnoses.tumor_stage,cases.exposures.years_smoked,cases.exposures.cigarettes_per_day,cases.samples.portions.analytes.aliquots.submitter_id",
    "format": "TSV",
    "size": "50000"
    }
response = requests.get("https://api.gdc.cancer.gov/files", headers = {"Content-Type": "application/json"}, params = params)
#print(response.content.decode("UTF-8"))
with open("files.txt","w") as files:
    files.write(response.content.decode("utf-8"))

# %%
df_files = pd.read_csv("files.txt", sep='\t')
df_files.drop("id", axis=1, inplace=True)
df_files.set_index("file_name", inplace=True)
df_files.rename(columns={"cases.0.samples.0.portions.0.analytes.0.aliquots.0.submitter_id":"sample_submitter_id"}, inplace=True)
df_files.head(2)
# Out:
#                                                   cases.0.demographic.days_to_birth  \
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz                           -25069.0
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz                           -27993.0
#
#                                                   cases.0.demographic.days_to_death  \
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz                              161.0
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz                             1790.0
#
#                                                  cases.0.demographic.gender  \
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz                       male
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz                     female
#
#                                                  cases.0.demographic.vital_status  \
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz                             Dead
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz                             Dead
#
#                                                   cases.0.diagnoses.0.age_at_diagnosis  \
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz                               25069.0
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz                               27993.0
#
#                                                   cases.0.diagnoses.0.days_to_last_follow_up  \
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz                                         NaN
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz                                         NaN
#
#                                                  cases.0.diagnoses.0.last_known_disease_status  \
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz                                  not reported
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz                                  not reported
#
#                                                   cases.0.exposures.0.cigarettes_per_day  \
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz                                1.369863
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz                                2.739726
#
#                                                   cases.0.exposures.0.years_smoked  \
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz                              15.0
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz                               NaN
#
#                                                  cases.0.project.project_id  \
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz                  TCGA-LUAD
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz                  TCGA-LUAD
#
#                                                            sample_submitter_id  \
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz  TCGA-MP-A4T8-01A-11R-A24X-07
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz  TCGA-MP-A4T6-01A-32R-A262-07
#
#                                                  cases.0.submitter_id
# file_name
# 12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz         TCGA-MP-A4T8
# 05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz         TCGA-MP-A4T6

# %%
df_files.to_csv("files_fpkm.dat", header=True)

# %% [markdown]
# # Merge

# %%
df_messangers = pd.read_csv("files_fpkm.dat")
df_messangers.head(2)
# Out:
#                                           file_name  \
# 0  12fff07f-74d6-4ee0-9f4f-36a4d194d24f.FPKM.txt.gz
# 1  05d2b1e9-22a4-4369-b622-63846d672875.FPKM.txt.gz
#
#    cases.0.demographic.days_to_birth  cases.0.demographic.days_to_death  \
# 0                           -25069.0                              161.0
# 1                           -27993.0                             1790.0
#
#   cases.0.demographic.gender cases.0.demographic.vital_status  \
# 0                       male                             Dead
# 1                     female                             Dead
#
#    cases.0.diagnoses.0.age_at_diagnosis  \
# 0                               25069.0
# 1                               27993.0
#
#    cases.0.diagnoses.0.days_to_last_follow_up  \
# 0                                         NaN
# 1                                         NaN
#
#   cases.0.diagnoses.0.last_known_disease_status  \
# 0                                  not reported
# 1                                  not reported
#
#    cases.0.exposures.0.cigarettes_per_day  cases.0.exposures.0.years_smoked  \
# 0                                1.369863                              15.0
# 1                                2.739726                               NaN
#
#   cases.0.project.project_id           sample_submitter_id  \
# 0                  TCGA-LUAD  TCGA-MP-A4T8-01A-11R-A24X-07
# 1                  TCGA-LUAD  TCGA-MP-A4T6-01A-32R-A262-07
#
#   cases.0.submitter_id
# 0         TCGA-MP-A4T8
# 1         TCGA-MP-A4T6

# %%
df_miRNA = pd.read_csv("files_miRNA.dat")
df_miRNA.head(2)
# Out:
#                                            file_name  \
# 0  03f54564-65bb-4561-ad33-ec78b883c217.mirbase21...
# 1  28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21...
#
#    cases.0.demographic.days_to_birth  cases.0.demographic.days_to_death  \
# 0                           -26451.0                                NaN
# 1                           -19200.0                                NaN
#
#   cases.0.demographic.gender cases.0.demographic.vital_status  \
# 0                     female                            Alive
# 1                     female                            Alive
#
#    cases.0.diagnoses.0.age_at_diagnosis  \
# 0                               26451.0
# 1                               19200.0
#
#    cases.0.diagnoses.0.days_to_last_follow_up  \
# 0                                       652.0
# 1                                       719.0
#
#   cases.0.diagnoses.0.last_known_disease_status  \
# 0                                  not reported
# 1                                  not reported
#
#    cases.0.exposures.0.cigarettes_per_day  cases.0.exposures.0.years_smoked  \
# 0                                1.643836                              24.0
# 1                                1.095890                               NaN
#
#   cases.0.project.project_id  cases.0.samples.0.longest_dimension  \
# 0                  TCGA-LUAD                                  0.8
# 1                  TCGA-LUAD                                  1.5
#
#       sample_submitter_id_mirna  cases.0.samples.0.shortest_dimension  \
# 0  TCGA-55-7726-11A-01H-2169-13                                   0.4
# 1  TCGA-44-7672-01A-11H-2065-13                                   0.8
#
#    cases.0.samples.0.tumor_descriptor cases.0.submitter_id
# 0                                 NaN         TCGA-55-7726
# 1                                 NaN         TCGA-44-7672

# %%
df_messangers = df_messangers.loc[~df_messangers["cases.0.submitter_id"].duplicated(keep="first"),:].rename(columns={"file_name":"file_fpkm"})
df_miRNA = df_miRNA.loc[~df_miRNA["cases.0.submitter_id"].duplicated(keep="first"),:].rename(columns={"file_name":"file_miRNA"})

# %%
df_files = df_miRNA.set_index("cases.0.submitter_id").transpose().append(df_messangers.set_index("cases.0.submitter_id").transpose()).transpose()
df_files.head(2)
# Out:
#                                                              file_miRNA  \
# cases.0.submitter_id
# TCGA-55-7726          03f54564-65bb-4561-ad33-ec78b883c217.mirbase21...
# TCGA-44-7672          28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21...
#
#                      cases.0.demographic.days_to_birth  \
# cases.0.submitter_id
# TCGA-55-7726                                  -26451.0
# TCGA-44-7672                                  -19200.0
#
#                      cases.0.demographic.days_to_death  \
# cases.0.submitter_id
# TCGA-55-7726                                       NaN
# TCGA-44-7672                                       NaN
#
#                      cases.0.demographic.gender  \
# cases.0.submitter_id
# TCGA-55-7726                             female
# TCGA-44-7672                             female
#
#                      cases.0.demographic.vital_status  \
# cases.0.submitter_id
# TCGA-55-7726                                    Alive
# TCGA-44-7672                                    Alive
#
#                      cases.0.diagnoses.0.age_at_diagnosis  \
# cases.0.submitter_id
# TCGA-55-7726                                      26451.0
# TCGA-44-7672                                      19200.0
#
#                      cases.0.diagnoses.0.days_to_last_follow_up  \
# cases.0.submitter_id
# TCGA-55-7726                                              652.0
# TCGA-44-7672                                              719.0
#
#                      cases.0.diagnoses.0.last_known_disease_status  \
# cases.0.submitter_id
# TCGA-55-7726                                          not reported
# TCGA-44-7672                                          not reported
#
#                      cases.0.exposures.0.cigarettes_per_day  \
# cases.0.submitter_id
# TCGA-55-7726                                       1.643836
# TCGA-44-7672                                        1.09589
#
#                      cases.0.exposures.0.years_smoked  ...  \
# cases.0.submitter_id                                   ...
# TCGA-55-7726                                     24.0  ...
# TCGA-44-7672                                      NaN  ...
#
#                      cases.0.demographic.days_to_death  \
# cases.0.submitter_id
# TCGA-55-7726                                       NaN
# TCGA-44-7672                                       NaN
#
#                      cases.0.demographic.gender  \
# cases.0.submitter_id
# TCGA-55-7726                             female
# TCGA-44-7672                             female
#
#                      cases.0.demographic.vital_status  \
# cases.0.submitter_id
# TCGA-55-7726                                    Alive
# TCGA-44-7672                                    Alive
#
#                      cases.0.diagnoses.0.age_at_diagnosis  \
# cases.0.submitter_id
# TCGA-55-7726                                      26451.0
# TCGA-44-7672                                      19200.0
#
#                      cases.0.diagnoses.0.days_to_last_follow_up  \
# cases.0.submitter_id
# TCGA-55-7726                                              652.0
# TCGA-44-7672                                              719.0
#
#                      cases.0.diagnoses.0.last_known_disease_status  \
# cases.0.submitter_id
# TCGA-55-7726                                          not reported
# TCGA-44-7672                                          not reported
#
#                      cases.0.exposures.0.cigarettes_per_day  \
# cases.0.submitter_id
# TCGA-55-7726                                       1.643836
# TCGA-44-7672                                        1.09589
#
#                      cases.0.exposures.0.years_smoked  \
# cases.0.submitter_id
# TCGA-55-7726                                     24.0
# TCGA-44-7672                                      NaN
#
#                      cases.0.project.project_id           sample_submitter_id
# cases.0.submitter_id
# TCGA-55-7726                          TCGA-LUAD  TCGA-55-7726-01A-11R-2170-07
# TCGA-44-7672                          TCGA-LUAD  TCGA-44-7672-01A-11R-2066-07
#
# [2 rows x 27 columns]

# %%
df_files.to_csv("files_manifest.dat")

# %% [markdown]
# Discordant LUSC are described in [Papaleo et al.; *BMC Cancers* (**2019**)](https://bmccancer.biomedcentral.com/articles/10.1186/s12885-019-5965-x)

# %%
df_discordant = pd.read_csv("https://raw.githubusercontent.com/ELELAB/LUAD_LUSC_TCGA_comparison/master/6-recount/LUSC/discordant_samples.txt", header=None)

df_biolinks = pd.read_csv("TCGA_biolinks.csv", index_col=0)
df_biolinks = df_biolinks[df_biolinks["cancer.type"].isin(["LUAD","LUSC"])]
df_biolinks.set_index("pan.samplesID", inplace=True)
df_biolinks.index = ["-".join(case.split("-")[:3]) for case in df_biolinks.index]
df_biolinks.head(2)
# Out:
#              cancer.type Subtype_mRNA Subtype_DNAmeth  Subtype_protein  \
# TCGA-05-4249        LUAD          NaN             NaN              NaN
# TCGA-05-4382        LUAD          NaN             NaN              NaN
#
#              Subtype_miRNA Subtype_CNA Subtype_Integrative Subtype_other  \
# TCGA-05-4249           NaN         NaN                   5           NaN
# TCGA-05-4382           NaN         NaN                   6           NaN
#
#              Subtype_Selected
# TCGA-05-4249           LUAD.5
# TCGA-05-4382           LUAD.6

# %%
def get_tissue_type(sample_id):
    try:
        return "normal" if int(sample_id.split("-")[3][:-1])>10 else "tumor"
    except:
        return sample_id

# %%
df_files["sample_submitter_id_type"]=list(map(get_tissue_type, df_files["sample_submitter_id"]))
df_files["sample_submitter_id_mirna_type"]=list(map(get_tissue_type, df_files["sample_submitter_id_mirna"]))

# %%
df_files = df_files.join(df_biolinks)
df_files = df_files.dropna(how="all", axis=0)
df_files.columns
for (sample,case) in zip(df_files.index,df_files["sample_submitter_id"]):
    if case in df_discordant.values.ravel():
        df_files.at[sample,"cancer.type"]="Discordant_LUSC"
df_files.to_csv("files.dat")
df_files.head(2)
# Out:
#                                                              file_miRNA  \
# cases.0.submitter_id
# TCGA-55-7726          03f54564-65bb-4561-ad33-ec78b883c217.mirbase21...
# TCGA-44-7672          28aeff63-ff53-417c-868c-156b9ee973c9.mirbase21...
#
#                      cases.0.demographic.days_to_birth  \
# cases.0.submitter_id
# TCGA-55-7726                                  -26451.0
# TCGA-44-7672                                  -19200.0
#
#                      cases.0.demographic.days_to_death  \
# cases.0.submitter_id
# TCGA-55-7726                                       NaN
# TCGA-44-7672                                       NaN
#
#                      cases.0.demographic.gender  \
# cases.0.submitter_id
# TCGA-55-7726                             female
# TCGA-44-7672                             female
#
#                      cases.0.demographic.vital_status  \
# cases.0.submitter_id
# TCGA-55-7726                                    Alive
# TCGA-44-7672                                    Alive
#
#                      cases.0.diagnoses.0.age_at_diagnosis  \
# cases.0.submitter_id
# TCGA-55-7726                                      26451.0
# TCGA-44-7672                                      19200.0
#
#                      cases.0.diagnoses.0.days_to_last_follow_up  \
# cases.0.submitter_id
# TCGA-55-7726                                              652.0
# TCGA-44-7672                                              719.0
#
#                      cases.0.diagnoses.0.last_known_disease_status  \
# cases.0.submitter_id
# TCGA-55-7726                                          not reported
# TCGA-44-7672                                          not reported
#
#                      cases.0.exposures.0.cigarettes_per_day  \
# cases.0.submitter_id
# TCGA-55-7726                                       1.643836
# TCGA-44-7672                                        1.09589
#
#                      cases.0.exposures.0.years_smoked  ...  \
# cases.0.submitter_id                                   ...
# TCGA-55-7726                                     24.0  ...
# TCGA-44-7672                                      NaN  ...
#
#                      sample_submitter_id_mirna_type cancer.type Subtype_mRNA  \
# cases.0.submitter_id
# TCGA-55-7726                                 normal        LUAD          NaN
# TCGA-44-7672                                  tumor        LUAD          NaN
#
#                      Subtype_DNAmeth Subtype_protein Subtype_miRNA  \
# cases.0.submitter_id
# TCGA-55-7726                     low             NaN           NaN
# TCGA-44-7672            intermediate             NaN           NaN
#
#                      Subtype_CNA Subtype_Integrative Subtype_other  \
# cases.0.submitter_id
# TCGA-55-7726                 NaN                   6           NaN
# TCGA-44-7672                 NaN                   6           NaN
#
#                      Subtype_Selected
# cases.0.submitter_id
# TCGA-55-7726                   LUAD.6
# TCGA-44-7672                   LUAD.6
#
# [2 rows x 38 columns]

# %%
df_files[["sample_submitter_id", "sample_submitter_id_type", "sample_submitter_id_mirna", "sample_submitter_id_mirna_type"]]
# Out:
#                                sample_submitter_id sample_submitter_id_type  \
# cases.0.submitter_id
# TCGA-55-7726          TCGA-55-7726-01A-11R-2170-07                    tumor
# TCGA-44-7672          TCGA-44-7672-01A-11R-2066-07                    tumor
# TCGA-50-5072          TCGA-50-5072-01A-21R-1858-07                    tumor
# TCGA-05-4425          TCGA-05-4425-01A-01R-1755-07                    tumor
# TCGA-69-A59K          TCGA-69-A59K-01A-11R-A262-07                    tumor
# ...                                            ...                      ...
# TCGA-22-4599          TCGA-22-4599-01A-01R-1443-07                    tumor
# TCGA-39-5016          TCGA-39-5016-01A-01R-1443-07                    tumor
# TCGA-21-1071          TCGA-21-1071-01A-01R-0692-07                    tumor
# TCGA-22-1002          TCGA-22-1002-01A-01R-0692-07                    tumor
# TCGA-18-3409          TCGA-18-3409-01A-01R-0980-07                    tumor
#
#                          sample_submitter_id_mirna  \
# cases.0.submitter_id
# TCGA-55-7726          TCGA-55-7726-11A-01H-2169-13
# TCGA-44-7672          TCGA-44-7672-01A-11H-2065-13
# TCGA-50-5072          TCGA-50-5072-01A-21H-1857-13
# TCGA-05-4425          TCGA-05-4425-01A-01T-1754-13
# TCGA-69-A59K          TCGA-69-A59K-01A-11H-A263-13
# ...                                            ...
# TCGA-22-4599                                   NaN
# TCGA-39-5016                                   NaN
# TCGA-21-1071                                   NaN
# TCGA-22-1002                                   NaN
# TCGA-18-3409                                   NaN
#
#                      sample_submitter_id_mirna_type
# cases.0.submitter_id
# TCGA-55-7726                                 normal
# TCGA-44-7672                                  tumor
# TCGA-50-5072                                  tumor
# TCGA-05-4425                                  tumor
# TCGA-69-A59K                                  tumor
# ...                                             ...
# TCGA-22-4599                                    NaN
# TCGA-39-5016                                    NaN
# TCGA-21-1071                                    NaN
# TCGA-22-1002                                    NaN
# TCGA-18-3409                                    NaN
#
# [1023 rows x 4 columns]

# %%
df_files["cancer.type"].unique()
# Out:
# array(['LUAD', nan, 'LUSC', 'Discordant_LUSC'], dtype=object)
